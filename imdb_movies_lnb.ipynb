# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("IMDB-Movie-Data (1).csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.columns  #show all the columns in the dataset
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.head(5)  #fetch first five rows data
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.info()  #provides meta information of the datset of the IMDB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.isnull().sum()   #provides the columns names with total number of the null values
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# List of columns to keep
essential_columns = ["Title", "Genre", "Director", "Rating", "Votes", "Revenue (Millions)"]

# Create a new DataFrame with only the essential columns
essential_data = df[essential_columns]

essential_data  

#we can also use drop func.
# df.drop(columns=columns_to_drop)
# Out:
#                        Title                     Genre              Director  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi            James Gunn
# 1                 Prometheus  Adventure,Mystery,Sci-Fi          Ridley Scott
# 2                      Split           Horror,Thriller    M. Night Shyamalan
# 3                       Sing   Animation,Comedy,Family  Christophe Lourdelet
# 4              Suicide Squad  Action,Adventure,Fantasy            David Ayer
# ..                       ...                       ...                   ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery             Billy Ray
# 996          Hostel: Part II                    Horror              Eli Roth
# 997   Step Up 2: The Streets       Drama,Music,Romance            Jon M. Chu
# 998             Search Party          Adventure,Comedy        Scot Armstrong
# 999               Nine Lives     Comedy,Family,Fantasy      Barry Sonnenfeld
#
#      Rating   Votes  Revenue (Millions)
# ...

# %%
df['Runtime (Minutes)'].mean()
# Out:
# 113.172

# %%
cm= df.groupby('Genre')['Title'].count().reset_index()
cm
# Out:
#                           Genre  Title
# 0                        Action      2
# 1              Action,Adventure      3
# 2    Action,Adventure,Biography      2
# 3       Action,Adventure,Comedy     14
# 4        Action,Adventure,Crime      6
# ..                          ...    ...
# 202     Romance,Sci-Fi,Thriller      1
# 203                      Sci-Fi      2
# 204             Sci-Fi,Thriller      1
# 205                    Thriller      9
# 206                Thriller,War      1
#
# [207 rows x 2 columns]

# %%
# Plotting the genre counts using a bar plot
plt.figure(figsize=(10, 6))
plt.bar(cm['Genre'],cm['Title'])
plt.ylabel("Number of Movies")
plt.xlabel("Genre")
plt.title("Number of Movies in Each Genre")
plt.show()

# %%
# Count the number of movies for each director
director_counts = df["Director"].value_counts()
# director_counts
# Get the top 5 directors
top_directors = director_counts.head(5)

# Print the top 5 directors
print(top_directors)
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Name: Director, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df["Year"].dtypes
# Out:
# dtype('int64')

# %%
nm=df.groupby('Year')['Title'].count().reset_index()
nm
# Out:
#     Year  Title
# 0   2006     44
# 1   2007     53
# 2   2008     52
# 3   2009     51
# 4   2010     60
# 5   2011     63
# 6   2012     64
# 7   2013     91
# 8   2014     98
# 9   2015    127
# 10  2016    297

# %%
# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(nm['Year'], nm['Title'], marker='o')
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.title("Number of Movies Released Each Year")
plt.grid(True)
plt.show()

# %%
#create a histogram of movies runtimes

plt.hist(df['Runtime (Minutes)'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel("Runtime (Minutes)")
plt.ylabel("Frequency")
plt.title("Distribution of Movie Runtimes")
plt.grid(True)
plt.show()

# %%
plt.hist(df['Rating'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.title("Distribution of Movie Ratings")
plt.grid(True)
plt.show()

# %%
# Calculate the correlation coefficient between movie ratings and runtimes
cf = df['Rating'].corr(df['Runtime (Minutes)'])

print("Correlation Coefficient:", cf)
# Out:
# Correlation Coefficient: 0.3922142455250512

# %%
# Combine all actor names into a single list
all_actors = df['Actors'].str.split(', ').explode()

# Count the occurrences of each actor
actor_counts = all_actors.value_counts()

# Get the top 3 most frequent actors
top_actors = actor_counts.head(3)

# Print the top 3 actors
print(top_actors)
# Out:
# Mark Wahlberg    15
# Brad Pitt        13
# Hugh Jackman     13
# Name: Actors, dtype: int64

# %%
# Create a scatter plot
# plt.figure(figsize=(10, 6))
plt.scatter(df['Rating'], df['Revenue (Millions)'])
plt.xlabel("Movie Rating")
plt.ylabel("Box Office Earnings (Millions)")
plt.title("Relationship between Movie Ratings and Box Office Earnings")
plt.grid(True)
plt.show()

# %%
from wordcloud import WordCloud

# Combine all movie titles into a single string
titles = " ".join(df['Title'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(titles)

# Display the WordCloud using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Movie Titles")
plt.show()

# %%
# Group the data by year and calculate the mean rating
average_ratings_by_year = df.groupby('Year')['Rating'].mean()

# Create a line plot
plt.plot(average_ratings_by_year.index, average_ratings_by_year.values, marker='o')
plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.title("Average Movie Ratings Over the Years")
plt.grid(True)
plt.show()

# %%
# Combine director and actor columns to create director-actor pairs
df['Director_Actor'] = df['Director'] + '-' + df['Actors']

# Count the occurrences of each director-actor pair
director_actor_counts = df['Director_Actor'].value_counts()

# Get the most common director-actor pairs
most_common_pairs = director_actor_counts.head()

# Print the most common director-actor pairs
print(most_common_pairs)
# Out:
# Francis Lawrence-Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson    2
# Michael Bay-Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                        2
# David Yates-Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon                 2
# James Gunn-Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana                         1
# Atom Egoyan-Colin Firth, Reese Witherspoon, Alessandro Nivola,James Hamrick             1
# Name: Director_Actor, dtype: int64

# %%
# Group the data by year and calculate the average runtime
average_runtime_by_year = df.groupby('Year')['Runtime (Minutes)'].mean()

# Create a line plot
plt.plot(average_runtime_by_year.index, average_runtime_by_year.values, marker='o')
plt.xlabel("Year")
plt.ylabel("Average Runtime (Minutes)")
plt.title("Average Movie Runtimes Over the Years")
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Rating'], df['Votes'], marker='o')
plt.xlabel("Rating")
plt.ylabel("no. of votes")
plt.grid(True)
plt.show()

# %%
rt = df.groupby('Rating')['Genre'].count().reset_index()
# rt
plt.hist(rt['Rating'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.title("the distribution of ratings for different genres")
plt.grid(True)
plt.show()

# %%
plt.boxplot(df['Runtime (Minutes)'])
plt.show()

# %%
outliers = []
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    q2 = np.percentile(data, 50)
    print("q1: ",q1,"\nq2: ",q2,"\nq3: ", q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    print("lwr_bound: ",lwr_bound, "\nupr_bound",upr_bound)
    for i in data: 
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers# Driver code
sample_outliers = detect_outliers_iqr(df['Runtime (Minutes)'])
print("Outliers from IQR method: ", sample_outliers)
#  print(lwr_bound, upr_bound)
# Out:
# q1:  100.0
# q2:  111.0
# q3:  123.0
# lwr_bound:  65.5
# upr_bound 157.5
# Outliers from IQR method:  [158, 158, 158, 158, 159, 160, 161, 161, 161, 162, 162, 162, 163, 164, 165, 165, 165, 165, 165, 166, 169, 169, 169, 170, 172, 180, 180, 180, 187, 191]

# %%
def manage_outliers(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    IQR = q3 - q1
    lower_bound = q1 - (1.5 * IQR)
    upper_bound = q3 + (1.5 * IQR)
    
    # Clip outliers to the upper and lower bounds
    data_clipped = np.clip(data, lower_bound, upper_bound)
    
    return data_clipped

# Apply the outlier management to your dataset column
df['Runtime (Minutes)'] = manage_outliers(df['Runtime (Minutes)'])

# %%
plt.boxplot(df['Runtime (Minutes)'])
plt.show()
